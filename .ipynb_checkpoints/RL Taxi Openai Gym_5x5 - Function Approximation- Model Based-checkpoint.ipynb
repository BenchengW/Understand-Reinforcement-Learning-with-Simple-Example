# %%
# !pip install cmake gym scipy
# Out:
# Requirement already satisfied: cmake in c:\users\admin\appdata\local\programs\python\python35\lib\site-packages (3.20.2)
# Requirement already satisfied: gym in c:\users\admin\appdata\local\programs\python\python35\lib\site-packages (0.17.3)
# Requirement already satisfied: scipy in c:\users\admin\appdata\local\programs\python\python35\lib\site-packages (1.3.3)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\admin\appdata\local\programs\python\python35\lib\site-packages (from gym) (1.17.4)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in c:\users\admin\appdata\local\programs\python\python35\lib\site-packages (from gym) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in c:\users\admin\appdata\local\programs\python\python35\lib\site-packages (from gym) (1.6.0)
# Requirement already satisfied: future in c:\users\admin\appdata\local\programs\python\python35\lib\site-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.18.2)
# DEPRECATION: Python 3.5 reached the end of its life on September 13th, 2020. Please upgrade your Python as Python 3.5 is no longer maintained. pip 21.0 will drop support for Python 3.5 in January 2021. pip 21.0 will remove support for this functionality.

# %%
import pandas as pd
import seaborn as sns
import itertools
import matplotlib
import numpy as np
import sys
import sklearn.pipeline
import sklearn.preprocessing
# from lib import plotting
from sklearn.linear_model import SGDRegressor
from sklearn.kernel_approximation import RBFSampler
from sklearn.preprocessing import LabelBinarizer


import gym
import itertools
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import sys
import sklearn.pipeline
import sklearn.preprocessing 

from sklearn.linear_model import SGDRegressor
from sklearn.kernel_approximation import RBFSampler

matplotlib.style.use('ggplot')

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import sys
from contextlib import closing
from io import StringIO
from gym import utils
from gym.envs.toy_text import discrete
import numpy as np

MAP = [
    "+---------+",
    "|R: | : :G|",
    "| : | : : |",
    "| : : : : |",
    "| | : | : |",
    "|Y| : |B: |",
    "+---------+",
]


# taxi_row, taxi_col, pass_idx, dest_idx = 3, 
# taxi_row, taxi_col, pass_idx, dest_idx = self.decode(self.s)


class TaxiEnv(discrete.DiscreteEnv):
    """
    The Taxi Problem
    from "Hierarchical Reinforcement Learning with the MAXQ Value Function Decomposition"
    by Tom Dietterich
    Description:
    There are four designated locations in the grid world indicated by R(ed), G(reen), Y(ellow), and B(lue). When the episode starts, the taxi starts off at a random square and the passenger is at a random location. The taxi drives to the passenger's location, picks up the passenger, drives to the passenger's destination (another one of the four specified locations), and then drops off the passenger. Once the passenger is dropped off, the episode ends.
    Observations:
    There are 500 discrete states since there are 25 taxi positions, 5 possible locations of the passenger (including the case when the passenger is in the taxi), and 4 destination locations. 
    Passenger locations:
    - 0: R(ed)
    - 1: G(reen)
    - 2: Y(ellow)
    - 3: B(lue)
    - 4: in taxi
    Destinations:
    - 0: R(ed)
    - 1: G(reen)
    - 2: Y(ellow)
    - 3: B(lue)
    Actions:
    There are 6 discrete deterministic actions:
    - 0: move south
    - 1: move north
    - 2: move east
    - 3: move west
    - 4: pickup passenger
    - 5: drop off passenger
    Rewards:
    There is a default per-step reward of -1,
    except for delivering the passenger, which is +20,
    or executing "pickup" and "drop-off" actions illegally, which is -10.
    Rendering:
    - blue: passenger
    - magenta: destination
    - yellow: empty taxi
    - green: full taxi
    - other letters (R, G, Y and B): locations for passengers and destinations
    state space is represented by:
        (taxi_row, taxi_col, passenger_location, destination)
    """
    metadata = {'render.modes': ['human', 'ansi']}

    def __init__(self):
        self.desc = np.asarray(MAP, dtype='c')

        self.locs = locs = [(0, 0), (0, 4), (4, 0), (4, 3)]

        num_states = 500
        num_rows = 5
        num_columns = 5
        max_row = num_rows - 1
        max_col = num_columns - 1
        initial_state_distrib = np.zeros(num_states)
        num_actions = 6
        P = {state: {action: []
                     for action in range(num_actions)} for state in range(num_states)}
        for row in range(num_rows):
            for col in range(num_columns):
                for pass_idx in range(len(locs) + 1):  # +1 for being inside taxi
                    for dest_idx in range(len(locs)):
                        state = self.encode(row, col, pass_idx, dest_idx)
                        if pass_idx < 4 and pass_idx != dest_idx:
                            initial_state_distrib[state] += 1
                        for action in range(num_actions):
                            # defaults
                            new_row, new_col, new_pass_idx = row, col, pass_idx
                            reward = -1  # default reward when there is no pickup/dropoff
                            done = False
                            taxi_loc = (row, col)

                            if action == 0:
                                new_row = min(row + 1, max_row)
                            elif action == 1:
                                new_row = max(row - 1, 0)
                            if action == 2 and self.desc[1 + row, 2 * col + 2] == b":":
                                new_col = min(col + 1, max_col)
                            elif action == 3 and self.desc[1 + row, 2 * col] == b":":
                                new_col = max(col - 1, 0)
                            elif action == 4:  # pickup
                                if (pass_idx < 4 and taxi_loc == locs[pass_idx]):
                                    new_pass_idx = 4
                                else:  # passenger not at location
                                    reward = -10
                            elif action == 5:  # dropoff
                                if (taxi_loc == locs[dest_idx]) and pass_idx == 4:
                                    new_pass_idx = dest_idx
                                    done = True
                                    reward = 20
                                elif (taxi_loc in locs) and pass_idx == 4:
                                    new_pass_idx = locs.index(taxi_loc)
                                else:  # dropoff at wrong location
                                    reward = -10
                            new_state = self.encode(
                                new_row, new_col, new_pass_idx, dest_idx)
                            P[state][action].append(
                                (1.0, new_state, reward, done))
        initial_state_distrib /= initial_state_distrib.sum()
        discrete.DiscreteEnv.__init__(
            self, num_states, num_actions, P, initial_state_distrib)

    def encode(self, taxi_row, taxi_col, pass_loc, dest_idx):
        # (5) 5, 5, 4
        i = taxi_row
        i *= 5
        i += taxi_col
        i *= 5
        i += pass_loc
        i *= 4
        i += dest_idx
        return i

    def decode(self, i):
        out = []
        out.append(i % 4)
        i = i // 4
        out.append(i % 5)
        i = i // 5
        out.append(i % 5)
        i = i // 5
        out.append(i)
        assert 0 <= i < 5
        return reversed(out)

    def render(self, mode='human'):
        outfile = StringIO() if mode == 'ansi' else sys.stdout

        out = self.desc.copy().tolist()
        out = [[c.decode('utf-8') for c in line] for line in out]
        taxi_row, taxi_col, pass_idx, dest_idx = self.decode(self.s)

        def ul(x): return "_" if x == " " else x
        if pass_idx < 4:
            out[1 + taxi_row][2 * taxi_col + 1] = utils.colorize(
                out[1 + taxi_row][2 * taxi_col + 1], 'yellow', highlight=True)
            pi, pj = self.locs[pass_idx]
            out[1 + pi][2 * pj + 1] = utils.colorize(out[1 + pi][2 * pj + 1], 'blue', bold=True)
        else:  # passenger in taxi
            out[1 + taxi_row][2 * taxi_col + 1] = utils.colorize(
                ul(out[1 + taxi_row][2 * taxi_col + 1]), 'green', highlight=True)

        di, dj = self.locs[dest_idx]
        out[1 + di][2 * dj + 1] = utils.colorize(out[1 + di][2 * dj + 1], 'magenta')
        outfile.write("\n".join(["".join(row) for row in out]) + "\n")
        if self.lastaction is not None:
            outfile.write("  ({})\n".format(["South", "North", "East", "West", "Pickup", "Dropoff"][self.lastaction]))
        else:
            outfile.write("\n")

        # No need to return anything for human
        if mode != 'human':
            with closing(outfile):
                return outfile.getvalue()

# %%
import gym
env = TaxiEnv()
state = env.encode(2, 2, 0, 3)
print("State:", state)
env.s = state
env.render()
# Out:
# State: 243
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
taxi_row, taxi_col, passenger_index, destination_index = env.decode(243)

# %%
labels = [0, 1, 2, 3, 4, 5]
lb = LabelBinarizer()
lb.fit(labels)
lb.transform([1])
# Out:
# array([[0, 1, 0, 0, 0, 0]])

# %%
observation_examples = np.array([list(env.decode(env.observation_space.sample())) for x in range(1000)])
scaler = sklearn.preprocessing.StandardScaler()

scaler.fit(observation_examples)
# Out:
# StandardScaler()

# %%
class Function_Approximator():
    
    def __init__(self):
        
        self.models = []
        for i in range(env.action_space.n):
            model = SGDRegressor(learning_rate="constant")
#             model.partial_fit([self.featurize_state([env.reset()])], [0])
            model.partial_fit([self.featurize_state(list(env.decode(env.reset())))], [0])
            self.models.append(model)
    
    def featurize_state(self, state):
        
        scaled = scaler.transform([state])
        return scaled[0]
    
    def predict(self, s, a=None):
        
        state_features = self.featurize_state(s)
        if not a:
            return np.array([m.predict([state_features])[0] for m in self.models])
        else:
            return self.models[a].predict([state_features])[0]
        
    def update(self, s, a, y):
       
        features = self.featurize_state(s)
        self.models[a].partial_fit([features], [y])

# %%
def make_epsilon_greedy_policy(estimator, epsilon, nA):
    
    def policy_fn(observation):
        A = np.ones(nA, dtype=float) * epsilon / nA
        q_values = estimator.predict(observation)
        best_action = np.argmax(q_values)
        A[best_action] += (1.0 - epsilon)
        return A
    return policy_fn

# %%
def q_learning(env, estimator, num_episodes, discount_factor=1.0, epsilon=0.3, epsilon_decay=1.0):
    
    # For plotting metrics
    all_epochs = []
    all_rewards = []
    
    for i_episode in range(num_episodes):
        
        epochs, penalties, cum_reward, = 0, 0, 0
        
        policy = make_epsilon_greedy_policy(estimator, epsilon * epsilon_decay**i_episode, env.action_space.n)
        state = env.reset()
        
        for t in itertools.count():
            
            state_feature = list(env.decode(state))
            
            action_probs = policy(state_feature)
            action = np.random.choice(np.arange(len(action_probs)), p=action_probs)
            
            next_state, reward, end, _ = env.step(action)
            
            
            next_state_feature = list(env.decode(next_state))
#             stats.episode_rewards[i_episode] += reward
#             stats.episode_lengths[i_episode] = t
            
            q_values_next = estimator.predict(next_state_feature)
            td_target = reward + discount_factor * np.max(q_values_next)
            
            estimator.update(state_feature, action, td_target)
            
            cum_reward += reward
            epochs += 1
            
            if end:
                break
                
            state = next_state
        print("\rEpisode {} with total epochs {} and cumulative reward {}".format(i_episode + 1, epochs, cum_reward))
        
        all_epochs.append(epochs)
        all_rewards.append(cum_reward)
    
    return all_epochs , all_rewards

# %%
# %%time
estimator = Function_Approximator()
all_epochs, all_rewards  = q_learning(env, estimator, 1000, epsilon=0.2)
# Out:
# Episode 1 with total epochs 949 and cumulative reward -1603
# Episode 2 with total epochs 1681 and cumulative reward -2668
# Episode 3 with total epochs 9704 and cumulative reward -15533
# Episode 4 with total epochs 1838 and cumulative reward -2789
# Episode 5 with total epochs 5686 and cumulative reward -8968
# Episode 6 with total epochs 11681 and cumulative reward -18311
# Episode 7 with total epochs 191 and cumulative reward -305
# Episode 8 with total epochs 3515 and cumulative reward -5393
# Episode 9 with total epochs 676 and cumulative reward -1096
# Episode 10 with total epochs 4352 and cumulative reward -6959
# Episode 11 with total epochs 461 and cumulative reward -764
# Episode 12 with total epochs 6599 and cumulative reward -10646
# Episode 13 with total epochs 2265 and cumulative reward -3657
# Episode 14 with total epochs 6388 and cumulative reward -10039
# Episode 15 with total epochs 5124 and cumulative reward -7992
# Episode 16 with total epochs 219 and cumulative reward -333
# Episode 17 with total epochs 3290 and cumulative reward -5312
# Episode 18 with total epochs 10292 and cumulative reward -16274
# Episode 19 with total epochs 12034 and cumulative reward -18727
# Episode 20 with total epochs 3556 and cumulative reward -5785
# Episode 21 with total epochs 1624 and cumulative reward -2665
# Episode 22 with total epochs 2853 and cumulative reward -4632
# Episode 23 with total epochs 5182 and cumulative reward -8077
# Episode 24 with total epochs 1117 and cumulative reward -1762
# Episode 25 with total epochs 3498 and cumulative reward -5619
# Episode 26 with total epochs 2835 and cumulative reward -4398
# Episode 27 with total epochs 2056 and cumulative reward -3304
# Episode 28 with total epochs 9619 and cumulative reward -15097
# Episode 29 with total epochs 4762 and cumulative reward -7549
# Episode 30 with total epochs 2288 and cumulative reward -3752
# Episode 31 with total epochs 3213 and cumulative reward -5190
# Episode 32 with total epochs 2391 and cumulative reward -3792
# Episode 33 with total epochs 266 and cumulative reward -344
# Episode 34 with total epochs 351 and cumulative reward -528
# Episode 35 with total epochs 1367 and cumulative reward -2165
# Episode 36 with total epochs 3098 and cumulative reward -4805
# Episode 37 with total epochs 3343 and cumulative reward -5401
# Episode 38 with total epochs 9568 and cumulative reward -15577
# Episode 39 with total epochs 3055 and cumulative reward -5032
# Episode 40 with total epochs 9325 and cumulative reward -14461
# Episode 41 with total epochs 1324 and cumulative reward -2131
# Episode 42 with total epochs 187 and cumulative reward -265
# Episode 43 with total epochs 2036 and cumulative reward -3266
# Episode 44 with total epochs 4719 and cumulative reward -7632
# Episode 45 with total epochs 11726 and cumulative reward -18581
# Episode 46 with total epochs 7817 and cumulative reward -12422
# Episode 47 with total epochs 4522 and cumulative reward -7012
# Episode 48 with total epochs 14811 and cumulative reward -23259
# Episode 49 with total epochs 4163 and cumulative reward -6644
# Episode 50 with total epochs 352 and cumulative reward -619
# Episode 51 with total epochs 3105 and cumulative reward -4920
# Episode 52 with total epochs 11489 and cumulative reward -18101
# Episode 53 with total epochs 3709 and cumulative reward -6019
# Episode 54 with total epochs 7785 and cumulative reward -12660
# Episode 55 with total epochs 53 and cumulative reward -68
# Episode 56 with total epochs 2787 and cumulative reward -4368
# Episode 57 with total epochs 8328 and cumulative reward -13149
# Episode 58 with total epochs 4439 and cumulative reward -6821
# Episode 59 with total epochs 7227 and cumulative reward -11706
# Episode 60 with total epochs 403 and cumulative reward -571
# Episode 61 with total epochs 773 and cumulative reward -1157
# Episode 62 with total epochs 7865 and cumulative reward -12569
# Episode 63 with total epochs 12426 and cumulative reward -19911
# Episode 64 with total epochs 5703 and cumulative reward -9498
# Episode 65 with total epochs 4643 and cumulative reward -7214
# Episode 66 with total epochs 3355 and cumulative reward -5386
# Episode 67 with total epochs 9436 and cumulative reward -14923
# Episode 68 with total epochs 76 and cumulative reward -91
# Episode 69 with total epochs 8107 and cumulative reward -12955
# Episode 70 with total epochs 4969 and cumulative reward -7720
# Episode 71 with total epochs 3084 and cumulative reward -5124
# Episode 72 with total epochs 1928 and cumulative reward -3041
# Episode 73 with total epochs 1775 and cumulative reward -2717
# Episode 74 with total epochs 1688 and cumulative reward -2702
# Episode 75 with total epochs 7739 and cumulative reward -12299
# Episode 76 with total epochs 8281 and cumulative reward -13093
# Episode 77 with total epochs 3013 and cumulative reward -4756
# Episode 78 with total epochs 425 and cumulative reward -611
# Episode 79 with total epochs 1588 and cumulative reward -2602
# Episode 80 with total epochs 818 and cumulative reward -1220
# Episode 81 with total epochs 7011 and cumulative reward -11031
# Episode 82 with total epochs 5670 and cumulative reward -8952
# Episode 83 with total epochs 23396 and cumulative reward -36893
# Episode 84 with total epochs 3223 and cumulative reward -5092
# Episode 85 with total epochs 3313 and cumulative reward -5236
# Episode 86 with total epochs 1190 and cumulative reward -1718
# Episode 87 with total epochs 3665 and cumulative reward -5588
# Episode 88 with total epochs 8013 and cumulative reward -12690
# Episode 89 with total epochs 2363 and cumulative reward -3845
# Episode 90 with total epochs 1975 and cumulative reward -3097
# Episode 91 with total epochs 9276 and cumulative reward -14439
# Episode 92 with total epochs 12122 and cumulative reward -19121
# Episode 93 with total epochs 73 and cumulative reward -97
# Episode 94 with total epochs 5730 and cumulative reward -8985
# Episode 95 with total epochs 493 and cumulative reward -724
# Episode 96 with total epochs 4566 and cumulative reward -7182
# Episode 97 with total epochs 2175 and cumulative reward -3540
# Episode 98 with total epochs 1147 and cumulative reward -1828
# Episode 99 with total epochs 2912 and cumulative reward -4475
# Episode 100 with total epochs 19288 and cumulative reward -31462
# Wall time: 9min 6s

# %%
data_tuples = list(zip(list(range(1, 101)), all_epochs, all_rewards))
learning_df = pd.DataFrame(data_tuples, columns=['episode','epochs_to_complete', 'rewards'])

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns_plot = sns.lineplot(x='episode', y='epochs_to_complete',data = learning_df[learning_df.episode<1000]).set(title='Epochs_to_complete Curve')

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns_plot = sns.lineplot(x='episode', y='epochs_to_complete',data = learning_df[learning_df.episode<1000]).set(title='Epochs_to_complete Curve')
